# %%
import juscraper as jus

# cria um objeto tjdft
tjdft = jus.scraper('tjdft')

# %%
# baixa dados da jurisprudência
dados_cjsg = tjdft.cjsg('direito penal', paginas=3)

print(dados_cjsg.shape)
dados_cjsg.head(3)
# Out:
# (30, 23)
#    sequencial      base   subbase                                  uuid  \
# 0          11  acordaos  acordaos  d473ef71-0aee-4875-b2cb-9204040050c5
# 1          12  acordaos  acordaos  9d4e7220-be1a-457f-ba36-378b44f86b0f
# 2          13  acordaos  acordaos  1784d7be-4b0d-4b15-8f20-d9a0dc48e6f7
#
#   identificador            dataJulgamento            dataPublicacao  \
# 0       2094008  2026-02-26T03:00:00.000Z  2026-03-05T18:36:17.000Z
# 1       2094028  2026-02-26T03:00:00.000Z  2026-03-05T18:13:46.000Z
# 2       2094027  2026-02-26T03:00:00.000Z  2026-03-05T18:11:38.000Z
#
#                                 decisao  \
# 0    ADMITIR E DENEGAR A ORDEM. UNÂNIME
# 1  NEGAR PROVIMENTO AO RECURSO. UNÂNIME
# 2  NEGAR PROVIMENTO AO RECURSO. UNÂNIME
#
#                                               ementa localDePublicacao  ...  \
# 0  EMENTA: DIREITO PENAL. HABEAS CORPUS. TRÁFICO ...               PJe  ...
# 1  DIREITO PENAL. APELAÇÃO CRIMINAL. LESÃO CORPOR...               PJe  ...
# 2  Ementa: DIREITO PENAL E PROCESSUAL PENAL. EMBA...               PJe  ...
#
#    uf segredoJustica  turmaRecursal descricaoOrgaoJulgador  versao  \
# 0  DF          False          False      1ª TURMA CRIMINAL      01
# 1  DF          False          False      1ª TURMA CRIMINAL      01
# 2  DF          False          False      1ª TURMA CRIMINAL      01
#
#    codigoClasseCnj codigoSistjOrgaoJulgador             inteiroTeorHtml  \
# 0              307                       51  Inteiro Teor indisponível.
# 1              417                       51  Inteiro Teor indisponível.
# 2              420                       51  Inteiro Teor indisponível.
#
#                                           marcadores  possuiInteiroTeor
# 0  {'ementa': ['EMENTA: <mark>DIREITO</mark> <mar...               True
# 1  {'ementa': ['<mark>DIREITO</mark> <mark>PENAL<...               True
# 2  {'ementa': ['Ementa: <mark>DIREITO</mark> <mar...               True
#
# [3 rows x 23 columns]

# %%
print(dados_cjsg['ementa'].iloc[0][:300])
# Out:
# EMENTA: DIREITO PENAL. HABEAS CORPUS. TRÁFICO DE DROGAS. PRISÃO PREVENTIVA. REVOGAÇÃO. IMPOSSIBILIDADE. REQUISITOS PRESENTES DA PRISÃO. RISCO À ORDEM PÚBLICA E APLICAÇÃO DA LEI PENAL.
#
# I.CASO EM EXAME
#
# 1. Habeas Corpus impetrado contra decisão do Juízo da 3ª Vara de Entorpecentes do DF que decreto

# %%
dados_cjsg['processo'].iloc[0]
# Out:
# '0702766-08.2026.8.07.0000'
