# %% [markdown]
# # TJAC - Tribunal de Justica do Acre
#
# Scraper for the jurisprudence search (CJSG) of the Tribunal de Justica do Acre.
#
# | Feature | Available |
# |---------|----------|
# | cjsg    | Yes      |
# | cpopg   | No       |
# | cposg   | No       |

# %% [markdown]
# ## Basic search

# %%
import juscraper as jus

tjac = jus.scraper('tjac')

# %%
df = tjac.cjsg('dano moral', paginas=range(1, 3))
print(df.shape)
df.head(3)
# Out:
# Baixando CJSG TJAC: 100%|██████████| 2/2 [00:01<00:00,  1.48s/it]
# Processando CJSG TJAC: 100%|██████████| 2/2 [00:00<00:00, 19.34it/s]
# (40, 10)
#                     processo cd_acordao cd_foro  \
# 0  0712323-18.2025.8.01.0001    2502928       0
# 1  0100293-66.2026.8.01.0000    2502948       0
# 2  0721736-89.2024.8.01.0001    2502950       0
#
#                                       classe_assunto  \
# 0              Apelação Cível / Alienação Fiduciária
# 1  Conflito de competência cível / Competência da...
# 2      Apelação Cível / Tratamento médico-hospitalar
#
#                    relatora     comarca        orgao_julgador data_julgamento  \
# 0  Desª. Waldirene Cordeiro  Rio Branco  Segunda Câmara Cível      08/04/2026
# 1       Des. Júnior Alberto  Rio Branco  Segunda Câmara Cível      07/04/2026
# 2  Desª. Waldirene Cordeiro  Rio Branco  Segunda Câmara Cível      07/04/2026
#
#   data_publicacao                                             ementa
# 0      08/04/2026  CIVIL. PROCESSO CIVIL. APELAÇÃO CÍVEL. BUSCA E...
# 1      08/04/2026  DIREITO PROCESSUAL CIVIL. CONFLITO NEGATIVO DE...
# 2      08/04/2026  CONSUMIDOR. PROCESSUAL CIVIL. DIREITO À SAÚDE....

# %% [markdown]
# ## Available columns

# %%
df.columns.tolist()
# Out:
# ['processo',
#  'cd_acordao',
#  'cd_foro',
#  'classe_assunto',
#  'relatora',
#  'comarca',
#  'orgao_julgador',
#  'data_julgamento',
#  'data_publicacao',
#  'ementa']

# %% [markdown]
# ## Preview ementa

# %%
print(df['ementa'].iloc[0][:300])
# Out:
# CIVIL. PROCESSO CIVIL. APELAÇÃO CÍVEL. BUSCA E APREENSÃO. ALIENAÇÃO FIDUCIÁRIA EM GARANTIA. INADIMPLEMENTO CONTRATUAL. NOTIFICAÇÃO EXTRAJUDICIAL. PURGAÇÃO DA MORA. PAGAMENTO INTEGRAL DA DÍVIDA. DECRETO-LEI Nº 911/69, ARTS. 2º, §2º, E 3º, §§1º E 2º. ALEGAÇÃO DE ABUSO DE DIREITO E VIOLAÇÃO À BOA-FÉ OB

# %% [markdown]
# ## Using filters
#
# You can filter by judgment date, publication date, decision type, and other fields.

# %%
df_filtered = tjac.cjsg(
    'direito',
    data_julgamento_inicio='01/01/2024',
    data_julgamento_fim='30/06/2024',
    paginas=1,
)
print(df_filtered.shape)
df_filtered.head(3)
# Out:
# Processando CJSG TJAC: 100%|██████████| 1/1 [00:00<00:00, 13.16it/s]
# (20, 10)
#                     processo cd_acordao cd_foro  \
# 0  0006503-64.2022.8.01.0001    2471902       0
# 1  0802195-83.2021.8.01.0001    2469395       0
# 2  0006536-20.2023.8.01.0001    2469403       0
#
#                                       classe_assunto               relatora  \
# 0                 Apelação Criminal / Roubo Majorado    Desª. Denise Bonfim
# 1              Apelação Criminal / Crimes de Tortura    Desª. Denise Bonfim
# 2  Apelação Criminal / Tráfico de Drogas e Condut...  Des. Francisco Djalma
#
#       comarca   orgao_julgador data_julgamento data_publicacao  \
# 0  Rio Branco  Câmara Criminal      27/06/2024      29/08/2024
# 1  Rio Branco  Câmara Criminal      21/05/2024      09/07/2024
# 2  Rio Branco  Câmara Criminal      27/06/2024      09/07/2024
#
#                                               ementa
# 0  PENAL. PROCESSUAL PENAL. APELAÇÕES CRIMINAIS D...
# 1  VV. APELAÇÃO CRIMINAL - LESÃO CORPORAL. TORTUR...
# 2  DIREITO PENAL. PROCESSO PENAL. TRÁFICO DE DROG...

# %% [markdown]
# ## Download and parse separately
#
# You can also download the raw HTML files and parse them in a separate step.

# %%
import tempfile, os

tmp = tempfile.mkdtemp()
pasta = tjac.cjsg_download('direito', paginas=1, diretorio=tmp)
print('Downloaded to:', pasta)
print('Files:', os.listdir(pasta))
# Out:
# Downloaded to: C:\Users\jtrec\AppData\Local\Temp\tmpez3zkxep\cjsg\20260409100826
# Files: ['cjsg_00001.html']

# %%
df_parsed = tjac.cjsg_parse(pasta)
print(df_parsed.shape)
df_parsed.head(3)
# Out:
# Processando CJSG TJAC: 100%|██████████| 1/1 [00:00<00:00, 24.95it/s]
# (20, 10)
#                     processo cd_acordao cd_foro  \
# 0  0800015-29.2023.8.01.0000    2502957       0
# 1  0000541-18.2022.8.01.0015    2502938       0
# 2  0000445-09.2022.8.01.0013    2502940       0
#
#                                       classe_assunto                 relatora  \
# 0  Procedimento Investigatório Criminal (PIC-MP) ...  Des. Samoel Evangelista
# 1          Apelação Criminal / Homicídio Qualificado  Des. Samoel Evangelista
# 2          Apelação Criminal / Homicídio Qualificado  Des. Samoel Evangelista
#
#        comarca                orgao_julgador data_julgamento data_publicacao  \
# 0   Rio Branco  Tribunal Pleno Jurisdicional      08/04/2026      09/04/2026
# 1  Mâncio Lima               Câmara Criminal      09/04/2026      09/04/2026
# 2        Feijó               Câmara Criminal      09/04/2026      09/04/2026
#
#                                               ementa
# 0  DIREITO PENAL E PROCESSUAL PENAL. INQUÉRITO. C...
# 1  DIREITO PENAL E PROCESSUAL PENAL. APELAÇÃO CRI...
# 2  Direito Penal e Processual Penal. Apelação Cri...
